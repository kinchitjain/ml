# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
# Out:
# Requirement already satisfied: Pillow in c:\users\kinch\anaconda3\lib\site-packages (7.2.0)
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0-cp37-none-win_amd64.whl (30.9 MB)
# Requirement already satisfied: numpy>=1.8.2 in c:\users\kinch\anaconda3\lib\site-packages (from scipy==1.1.0) (1.18.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\kinch\\anaconda3\\lib\\site-packages\\~cipy\\fft\\_pocketfft\\pypocketfft.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %%
# Out:
# Mounted at /content/gdrive

# %%
def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00050.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00052.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00054.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00056.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00058.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00060.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00062.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00001.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00003.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00005.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00007.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00011.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00013.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00019.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00025.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00047.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00049.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00053.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00055.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00059.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00004.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00006.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00008.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00010.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00012.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00014.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00016.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00018.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00020.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00022.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00024.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00026.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00028.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00030.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00032.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00034.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00036.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00038.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00040.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00042.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00044.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00046.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00048.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00050.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00052.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00054.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00056.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00058.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00060.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00062.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00016.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00018.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00019.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00020.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00022.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00024.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00025.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00026.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00028.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00030.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00032.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00034.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00036.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00038.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00040.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00042.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00044.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00006.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00008.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00010.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00012.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00014.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00016.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00018.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00020.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00022.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00024.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00026.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00028.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00030.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00032.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00034.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00036.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00038.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00040.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00042.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00044.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00046.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00048.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00050.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00052.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00054.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00056.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00058.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00060.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00062.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00064.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00003.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00005.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00007.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00011.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00013.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00019.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00025.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00047.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00049.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00053.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00055.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00059.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00061.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00005.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00007.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00011.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00013.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00019.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00025.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00047.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00049.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00053.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00055.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00059.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00061.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00063.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00013.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00015.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00017.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00019.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00021.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00023.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00025.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00027.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00029.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00031.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00033.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00035.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00037.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00039.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00041.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00043.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00045.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00047.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00049.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00051.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00053.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00055.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00057.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00059.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00061.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00063.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00065.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00067.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00069.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00071.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00001.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00003.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00005.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00007.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00009.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00011.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00013.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00015.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00017.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00019.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00021.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00023.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00025.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00027.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00033.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00037.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00039.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00041.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00043.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00047.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00049.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00051.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00053.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00055.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00059.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00003.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00006.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00012.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00018.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00024.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00030.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00036.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00042.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00048.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00054.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00060.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00063.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00066.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00069.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00072.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00075.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00078.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00081.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00084.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00087.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00090.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00006.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00012.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00018.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00024.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00030.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00036.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00042.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00048.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00054.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00060.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00063.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00066.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00069.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00072.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00075.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00078.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00081.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00084.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00087.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00090.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00093.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00007.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00011.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00013.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00019.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00025.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00041.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00045.png
# ...
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00033.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00037.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00039.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00047.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00049.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00053.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00055.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00057.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00059.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00061.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00063.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00065.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00011.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00013.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00019.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00025.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00027.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00047.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00049.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00053.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00055.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00059.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00061.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00063.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00065.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00067.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00001.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00003.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00005.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00007.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00011.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00013.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00019.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00025.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00047.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00049.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00051.png
#   inflating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00053.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00055.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00059.png
#    creating: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00009.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00011.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00013.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00015.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00017.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00019.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00021.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00023.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00025.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00027.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00029.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00031.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00033.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00035.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00037.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00039.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00041.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00043.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00045.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00047.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00049.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00051.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00053.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00055.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00057.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00059.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00061.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00063.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00065.png
#  extracting: /content/gdrive/My Drive/gesture/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00067.png

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
#data_dir_train = pathlib.Path("/content/gdrive/My Drive/cnn/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
#data_dir_test = pathlib.Path('/content/gdrive/My Drive/cnn/Skin cancer ISIC The International Skin Imaging Collaboration/Test/')
train_doc = np.random.permutation(open('C:\\Project_data\\Project_data\\train.csv').readlines())
val_doc = np.random.permutation(open('C:\\Project_data\\Project_data\\val.csv').readlines())
batch_size =20 #experiment with the batch size

project_folder='c:\\Project_data\\Project_data'

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class ModelBuilder:
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=imresize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=imresize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'C:\\Project_data\\Project_data\\train'
val_path = 'C:\\Project_data\\Project_data\\val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs =20 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 20

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.layers import Dropout


#write your model here

class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        #optimiser = 'sgd'
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=40,num_epochs=1)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation (Activation)      (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_1 (Activation)    (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1638528
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________

# %%
import sys
print("Memory util is {} Gigs". format(sys.getsizeof(np.zeros((40,16,30,160,160)))/(1024*1024*1024)))
# Out:
# Memory util is 3.662109524011612 Gigs

# %%
#So lets trade-off between these parameters¶
#Below are the experiments to see how training time is affected by image resolution, number of images in sequence and batch size

conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=3)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# C:\Users\kinch\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# C:\Users\kinch\anaconda3\lib\site-packages\ipykernel_launcher.py:55: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
# C:\Users\kinch\anaconda3\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``skimage.transform.resize`` instead.
# Epoch 1/3
# 23/23 [==============================] - 1193s 52s/step - loss: 1.8933 - categorical_accuracy: 0.3260 - val_loss: 2.5098 - val_categorical_accuracy: 0.1800
#
# Epoch 00001: saving model to model_init_2021-01-2322_29_15.128052\model-00001-1.50968-0.43288-2.50981-0.18000.h5
# Epoch 2/3
# 23/23 [==============================] - 1224s 53s/step - loss: 0.8028 - categorical_accuracy: 0.6625 - val_loss: 5.4558 - val_categorical_accuracy: 0.2200
#
# Epoch 00002: saving model to model_init_2021-01-2322_29_15.128052\model-00002-0.84397-0.65460-5.45581-0.22000.h5
# Epoch 3/3
# 23/23 [==============================] - 1162s 51s/step - loss: 0.6005 - categorical_accuracy: 0.7575 - val_loss: 6.6056 - val_categorical_accuracy: 0.2100
#
# Epoch 00003: saving model to model_init_2021-01-2322_29_15.128052\model-00003-0.62151-0.74661-6.60557-0.21000.h5

# %% [markdown]
# conv_3d1=ModelConv3D1()
# conv_3d1.initialize_path(project_folder)
# conv_3d1.initialize_image_properties(image_height=100,image_width=100)
# conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=30,num_epochs=2)
# conv_3d1_model=conv_3d1.define_model()
# print("Total Params:", conv_3d1_model.count_params())
# conv_3d1.train_model(conv_3d1_model)

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=60,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)

# %% [markdown]
# #As we see from the above experiments image resolution and number of frames in sequence have more #impact on training time than batch_size
# #So experimentations are carried with batch size fixed around 15-40 and changing the resolution and #number of image per sequence based on the device memory constraints . Models are designed such that #their memory foot print is less than 50 MB which corresponds to 4.3 million parameters assuming the #datatype size of parameters to be 12 bytes

# %%
#Model 1 - Base Model - No Data Augmentation Batch Size 40 and Epoch 15¶
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_8 (Conv3D)            (None, 20, 160, 160, 16)  1312
# _________________________________________________________________
# activation_8 (Activation)    (None, 20, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 20, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 10, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 10, 80, 80, 32)    13856
# _________________________________________________________________
# activation_9 (Activation)    (None, 10, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 10, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 5, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 5, 40, 40, 64)     55360
# _________________________________________________________________
# activation_10 (Activation)   (None, 5, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 2, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 2, 20, 20, 128)    221312
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 2, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                819264
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# C:\Users\kinch\anaconda3\lib\site-packages\ipykernel_launcher.py:55: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
# C:\Users\kinch\anaconda3\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``skimage.transform.resize`` instead.
# Epoch 1/15

# %%
plot(history_model1)

# %%
#Model is clearly overfitting. So we need to do data augmentation¶
